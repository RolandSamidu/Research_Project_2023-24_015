# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model

model = load_model('/content/FV.h5')

# %%
model.save('/content/drive/MyDrive/Heart App 2/models/Calory Model', save_format='tf')

# %%
model.save("calory.keras")
