# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
diet_data = pd.read_csv('/content/drive/MyDrive/Research Models/Diet Plan Prediction/Dataset.csv')

# %%
diet_data.head()
# Out:
#    Unnamed: 0  age  weight(kg)  height(m) gender        BMI      BMR  \
# 0           1    2   16.097862   0.932025      F  18.531612  958.584
# 1           2    4   14.619374   0.916687      F  17.397496  932.383
# 2           4    4   17.899918   0.997288      F  17.997414  977.578
# 3           6    3   13.532880   1.022786      F  12.936609  944.689
# 4           8    4   17.039484   1.053977      M  15.338909  799.229
#
#    activity_level  calories_to_maintain_weight  BMI_tags  Label
# 0             1.2                    1150.3008         8     13
# 1             1.7                    1585.0511         7      1
# 2             1.9                    1857.3982         7      4
# 3             1.9                    1794.9091         7      3
# 4             1.9                    1518.5351         7      0

# %%
diet_data.shape
# Out:
# (10726, 11)

# %%
diet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10726 entries, 0 to 10725
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   10726 non-null  int64
#  1   age                          10726 non-null  int64
#  2   weight(kg)                   10726 non-null  float64
#  3   height(m)                    10726 non-null  float64
#  4   gender                       10726 non-null  object
#  5   BMI                          10726 non-null  float64
#  6   BMR                          10726 non-null  float64
#  7   activity_level               10726 non-null  float64
#  8   calories_to_maintain_weight  10726 non-null  float64
#  9   BMI_tags                     10726 non-null  int64
#  10  Label                        10726 non-null  int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 921.9+ KB

# %%
diet_data.columns
# Out:
# Index(['Unnamed: 0', 'age', 'weight(kg)', 'height(m)', 'gender', 'BMI', 'BMR',
#        'activity_level', 'calories_to_maintain_weight', 'BMI_tags', 'Label'],
#       dtype='object')

# %%
diet_data.isnull().sum()
# Out:
# Unnamed: 0                     0
# age                            0
# weight(kg)                     0
# height(m)                      0
# gender                         0
# BMI                            0
# BMR                            0
# activity_level                 0
# calories_to_maintain_weight    0
# BMI_tags                       0
# Label                          0
# dtype: int64

# %%
diet_data.describe()
# Out:
#          Unnamed: 0           age    weight(kg)     height(m)           BMI  \
# count  10726.000000  10726.000000  10726.000000  10726.000000  10726.000000
# mean   11664.753123     26.778575     61.647728      1.540276     24.788317
# std     6814.683196     18.201675     24.254566      0.186042      6.954637
# min        1.000000      2.000000     12.005536      0.856328     10.342285
# 25%     5959.750000     13.000000     45.538375      1.564845     19.557137
# 50%    10695.500000     23.000000     61.323460      1.631282     23.056039
# 75%    17455.250000     36.000000     83.484585      1.632234     31.334294
# max    23998.000000     90.000000     98.799820      1.633223     37.142927
#
#                 BMR  activity_level  calories_to_maintain_weight  \
# count  10726.000000    10726.000000                 10726.000000
# mean    1442.049923        1.487451                  2118.574075
# std      250.686166        0.239625                   388.425427
# ...

# %%
diet_data['gender'] = diet_data['gender'].replace({'F': 0, 'M': 1})

# %%
diet_data['calories_to_maintain_weight'] = diet_data['calories_to_maintain_weight'].astype(int)

# %% [markdown]
# For X Predicates     -> other
# For Y                -> calories_to_maintain_weight

# %%
X = diet_data.drop(columns='calories_to_maintain_weight', axis=1)
Y = diet_data['calories_to_maintain_weight']

# %%
print(X)
# Out:
#        Unnamed: 0  age  weight(kg)  height(m)  gender        BMI       BMR  \
# 0               1    2   16.097862   0.932025       0  18.531612   958.584
# 1               2    4   14.619374   0.916687       0  17.397496   932.383
# 2               4    4   17.899918   0.997288       0  17.997414   977.578
# 3               6    3   13.532880   1.022786       0  12.936609   944.689
# 4               8    4   17.039484   1.053977       1  15.338909   799.229
# ...           ...  ...         ...        ...     ...        ...       ...
# 10721       23986   72   95.444236   1.631113       0  35.874169  1510.154
# 10722       23988   85   97.976899   1.631409       0  36.812724  1473.418
# 10723       23994   50   97.761259   1.631864       0  36.711217  1635.925
# 10724       23997   57   96.829324   1.631290       0  36.386871  1593.981
# 10725       23998   63   97.615186   1.633168       1  36.597850  1791.512
#
#        activity_level  BMI_tags  Label
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (10726, 10) (8580, 10) (2146, 10)

# %% [markdown]
# **MODEL TRAINING**

# %%
MODEL = LogisticRegression()

# %%
# Y_train = Y_train.astype(int)

# %%
print(Y_train.unique())
# Out:
# [2150 2773 2233 ... 2809 1197 1189]

# %%
print(diet_data.dtypes)
# Out:
# Unnamed: 0                       int64
# age                              int64
# weight(kg)                     float64
# height(m)                      float64
# gender                           int64
# BMI                            float64
# BMR                            float64
# activity_level                 float64
# calories_to_maintain_weight      int64
# BMI_tags                         int64
# Label                            int64
# dtype: object

# %%
MODEL.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = MODEL.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.004662004662004662
